# %%
import wave
import IPython
from pydub import AudioSegment
from pydub import effects
import boto3
import srt
from pathlib import Path
import os
import string
import time

polly = boto3.client('polly')

# %%
def addSilence(duration):
    """
    duration - duration in ms
    """
    silentSegment = AudioSegment.silent(duration=duration)
    return silentSegment

# %%
def speedChange(audioClip, speed=1.01):
    if speed < 1.1:
        fast = audioClip.speedup(speed, 150, 25)
    else:
        fast = audioClip.speedup(speed, 50, 5)
    return fast

# %%
en_FEMALE = 'Joanna'
en_MALE = 'Matthew'
es_MALE = 'Miguel'
def genSound(id, outputDir, text):
    
    ssml = "<speak>" + "<amazon:auto-breaths>" + text + "</amazon:auto-breaths>" + "</speak>"
    #res = polly.synthesize_speech(Text=text, TextType='text', Engine='standard',VoiceId=es_MALE, OutputFormat='mp3')
    res = polly.synthesize_speech(Text=text, TextType='text', Engine='neural',VoiceId=en_FEMALE, OutputFormat='mp3')
    #res = polly.synthesize_speech(Text=ssml, TextType='ssml', Engine='standard',VoiceId='Salli', OutputFormat='mp3')
    body = res['AudioStream'].read()
    fileName = outputDir + '/' + id + '.mp3'
    
    with open(fileName, 'wb') as file:
        file.write(body)
        file.close()

# %%
def processSubtitles():
    audio_out_file = None
    while True:
        try:
            # Get the subtitle filepath
            message = "Subtitle file: Enter an subtitle filepath of the voice captions to be generated (srt):\n"
            in_subpath = Path(input(message).replace("\"", "").replace("\'", ""))
        
            # Load subtitle to be processed
            srt_file = Path(in_subpath).read_text()
            print("Processing: ", in_subpath)
            if(not os.path.isdir('output')):
                    os.makedirs("output")
            
            subs = list(srt.parse(srt_file))
            currentTime = 0
            delay = 0
            padding = 0
            for sub in subs:
                if sub.index > 0:
                    print(f'Processing subtitle {sub.index}/{len(subs)}')
                    print(f'\tContent: {sub.content}')
                    # Calculate length of silence to add
                    print(f'\tStart: {sub.start}')
                    print(f'\tEnd: {sub.end}')

                    #clean_text = sub.content.translate(str.maketrans("", "", string.punctuation))
                    #print(f'Stripped text: {clean_text}')

                    ## Generating the spectrogram

                    print(f'\tCreating: output/{str(sub.index)}.mp3')
                    genSound(str(sub.index), 'output', str(sub.content))

                    # Add silence and stitch files
                    audio = AudioSegment.from_mp3('output/'+str(sub.index)+'.mp3')

                    if currentTime == 0:
                        padding = (sub.start.total_seconds() * 1000) - currentTime
                        currentTime += padding + len(audio)
                        audio_out_file = addSilence(padding) + audio
                    else:
                        if padding < 0:
                            # Speed change
                            speed = round(((-1*padding)+len(audio))/len(audio),2)
                            if speed > 1.0:
                                newAudio = speedChange(audio, speed)
                                audio = newAudio
                            print(f'\tSpeed: {speed}')
                            padding = 0
                            currentTime += padding + len(audio)
                            audio_out_file += audio
                                
                        else:
                            padding = (sub.start.total_seconds() * 1000) - currentTime
                            currentTime += padding + len(audio)                   
                            audio_out_file += addSilence(padding) + audio

                    print(f'\tPadding: {padding}')
                    print(f'\tclip len: {len(audio)}')
                    print(f'\tcurrentTime: {currentTime}')

            # Get the subtitle filepath
            message = "Output file: Enter a name for the output file  (wav):\n"
            out_name = input(message)
            print(f'\tExporting: {out_name}.wav')
            audio_out_file.export(f'{out_name}.wav', format="wav")

                
        except Exception as e:
            print("Caught exception: %s" % repr(e))
            print("Restarting\n")

# %%
processSubtitles()
# Out:
# Subtitle file: Enter an subtitle filepath of the voice captions to be generated (srt):
# ivan.srt
# Processing:  ivan.srt
# Processing subtitle 1/107
# 	Content: "Look at me!"
# 	Start: 0:00:04.782000
# 	End: 0:00:06.161000
# 	Creating: output/1.mp3
# 	Padding: 4782.0
# 	clip len: 816
# 	currentTime: 5598.0
# Processing subtitle 2/107
# 	Content: That phrase turned me
# into an eye-contact coach.
# 	Start: 0:00:08.180000
# 	End: 0:00:12.805000
# 	Creating: output/2.mp3
# 	Padding: 2582.0
# 	clip len: 2664
# 	currentTime: 10844.0
# Processing subtitle 3/107
# 	Content: I am the mother of Ivan. He is 15 years old.
# 	Start: 0:00:14.299000
# 	End: 0:00:17.243000
# 	Creating: output/3.mp3
# 	Padding: 3455.0
# 	clip len: 3432
# 	currentTime: 17731.0
# Processing subtitle 4/107
# 	Content: Ivan has autism,
# 	Start: 0:00:18.023000
# 	End: 0:00:19.967000
# 	Creating: output/4.mp3
# 	Padding: 292.0
# 	clip len: 1464
# 	currentTime: 19487.0
# Processing subtitle 5/107
# 	Content: he doesn't speak,
# 	Start: 0:00:19.991000
# 	End: 0:00:21.536000
# 	Creating: output/5.mp3
# 	Padding: 504.0
# 	clip len: 1200
# 	currentTime: 21191.0
# Processing subtitle 6/107
# 	Content: and he communicates through an iPad,
# 	Start: 0:00:21.560000
# 	End: 0:00:23.550000
# 	Creating: output/6.mp3
# 	Padding: 369.0
# 	clip len: 2064
# 	currentTime: 23624.0
# Processing subtitle 7/107
# 	Content: where his whole universe of words
# exists in images.
# 	Start: 0:00:23.574000
# 	End: 0:00:27.446000
# 	Creating: output/7.mp3
# 	Padding: -50.0
# 	clip len: 2928
# 	currentTime: 26502.0
# Processing subtitle 8/107
# 	Content: He was diagnosed
# when he was two and a half.
# 	Start: 0:00:29.451000
# 	End: 0:00:33.993000
# 	Creating: output/8.mp3
# 	Speed: 1.02
# 	Padding: 0
# 	clip len: 2357
# 	currentTime: 28859.0
# Processing subtitle 9/107
# 	Content: I still remember that day painfully.
# 	Start: 0:00:35.211000
# 	End: 0:00:39.224000
# 	Creating: output/9.mp3
# 	Padding: 6352.0
# 	clip len: 2088
# 	currentTime: 37299.0
# Processing subtitle 10/107
# 	Content: My husband and I felt really lost;
# 	Start: 0:00:40.983000
# 	End: 0:00:43.716000
# 	Creating: output/10.mp3
# 	Padding: 3684.0
# 	clip len: 2280
# 	currentTime: 43263.0
# Processing subtitle 11/107
# 	Content: we didn't know where to begin.
# 	Start: 0:00:44.993000
# 	End: 0:00:47.171000
# 	Creating: output/11.mp3
# 	Padding: 1730.0
# 	clip len: 1536
# 	currentTime: 46529.0
# Processing subtitle 12/107
# 	Content: There was no internet,
# 	Start: 0:00:48.444000
# 	End: 0:00:50.869000
# 	Creating: output/12.mp3
# 	Padding: 1915.0
# 	clip len: 1368
# 	currentTime: 49812.0
# Processing subtitle 13/107
# 	Content: you couldn't Google information,
# 	Start: 0:00:50.893000
# 	End: 0:00:53.323000
# 	Creating: output/13.mp3
# 	Padding: 1081.0
# 	clip len: 1800
# 	currentTime: 52693.0
# Processing subtitle 14/107
# 	Content: so we made those first steps
# 	Start: 0:00:54.209000
# 	End: 0:00:56.186000
# 	Creating: output/14.mp3
# 	Padding: 1516.0
# 	clip len: 1752
# 	currentTime: 55961.0
# Processing subtitle 15/107
# 	Content: out of sheer intuition.
# 	Start: 0:00:57.123000
# 	End: 0:00:59.249000
# 	Creating: output/15.mp3
# 	Padding: 1162.0
# 	clip len: 1488
# 	currentTime: 58611.0
# Processing subtitle 16/107
# 	Content: Ivan would not maintain eye contact,
# 	Start: 0:01:01.353000
# 	End: 0:01:03.443000
# 	Creating: output/16.mp3
# 	Padding: 2742.0
# 	clip len: 2088
# 	currentTime: 63441.0
# Processing subtitle 17/107
# 	Content: he had lost the words that he did know,
# 	Start: 0:01:04.515000
# 	End: 0:01:06.764000
# 	Creating: output/17.mp3
# 	Padding: 1074.0
# 	clip len: 2088
# 	currentTime: 66603.0
# Processing subtitle 18/107
# 	Content: and he didn't respond to his name
# or to anything we asked him,
# 	Start: 0:01:07.788000
# 	End: 0:01:11.765000
# 	Creating: output/18.mp3
# 	Padding: 1185.0
# 	clip len: 3264
# 	currentTime: 71052.0
# Processing subtitle 19/107
# 	Content: as if words were noise.
# 	Start: 0:01:12.573000
# 	End: 0:01:14.860000
# 	Creating: output/19.mp3
# 	Padding: 1521.0
# 	clip len: 1392
# 	currentTime: 73965.0
# Processing subtitle 20/107
# 	Content: The only way I could know
# 	Start: 0:01:16.971000
# 	End: 0:01:20.879000
# 	Creating: output/20.mp3
# 	Padding: 3006.0
# 	clip len: 1536
# 	currentTime: 78507.0
# Processing subtitle 21/107
# 	Content: what was going on with him,
# 	Start: 0:01:21.521000
# 	End: 0:01:23.139000
# 	Creating: output/21.mp3
# 	Padding: 3014.0
# 	clip len: 1536
# 	currentTime: 83057.0
# Processing subtitle 22/107
# 	Content: what he felt,
# 	Start: 0:01:23.807000
# 	End: 0:01:25.306000
# 	Creating: output/22.mp3
# 	Padding: 750.0
# 	clip len: 1008
# 	currentTime: 84815.0
# Processing subtitle 23/107
# 	Content: was looking him in the eye.
# 	Start: 0:01:25.841000
# 	End: 0:01:27.700000
# 	Creating: output/23.mp3
# 	Padding: 1026.0
# 	clip len: 1392
# 	currentTime: 87233.0
# Processing subtitle 24/107
# 	Content: But that bridge was broken.
# 	Start: 0:01:29.313000
# 	End: 0:01:31.466000
# 	Creating: output/24.mp3
# 	Padding: 2080.0
# 	clip len: 1584
# 	currentTime: 90897.0
# Processing subtitle 25/107
# 	Content: How could I teach him about life?
# 	Start: 0:01:34.125000
# 	End: 0:01:36.556000
# 	Creating: output/25.mp3
# 	Padding: 3228.0
# 	clip len: 1824
# 	currentTime: 95949.0
# Processing subtitle 26/107
# 	Content: When I did things he liked,
# he would look at me,
# 	Start: 0:01:39.023000
# 	End: 0:01:42.931000
# 	Creating: output/26.mp3
# 	Padding: 3074.0
# 	clip len: 2448
# 	currentTime: 101471.0
# Processing subtitle 27/107
# 	Content: and we were connected.
# 	Start: 0:01:42.955000
# 	End: 0:01:44.489000
# 	Creating: output/27.mp3
# 	Padding: 1484.0
# 	clip len: 1200
# 	currentTime: 104155.0
# Processing subtitle 28/107
# 	Content: So I dedicated myself
# to working with him on those things,
# 	Start: 0:01:45.389000
# 	End: 0:01:48.957000
# 	Creating: output/28.mp3
# 	Padding: 1234.0
# 	clip len: 3096
# 	currentTime: 108485.0
# Processing subtitle 29/107
# 	Content: so we would have more and more
# eye-contact moments.
# 	Start: 0:01:48.981000
# 	End: 0:01:53.310000
# 	Creating: output/29.mp3
# 	Padding: 496.0
# 	clip len: 2592
# 	currentTime: 111573.0
# Processing subtitle 30/107
# 	Content: We would spend hours and hours playing tag
# with his older sister, Alexia,
# 	Start: 0:01:54.794000
# 	End: 0:02:01.315000
# 	Creating: output/30.mp3
# 	Padding: 3221.0
# 	clip len: 4368
# 	currentTime: 119162.0
# Processing subtitle 31/107
# 	Content: and when we said: "I caught you!"
# 	Start: 0:02:02.006000
# 	End: 0:02:04.623000
# 	Creating: output/31.mp3
# 	Padding: 2844.0
# 	clip len: 2040
# 	currentTime: 124046.0
# Processing subtitle 32/107
# 	Content: he would look around for us,
# 	Start: 0:02:05.690000
# 	End: 0:02:07.384000
# 	Creating: output/32.mp3
# 	Padding: 1644.0
# 	clip len: 1536
# 	currentTime: 127226.0
# Processing subtitle 33/107
# 	Content: and at that moment,
# I could feel he was alive.
# 	Start: 0:02:08.474000
# 	End: 0:02:13.213000
# 	Creating: output/33.mp3
# 	Padding: 1247.9999999999854
# 	clip len: 2592
# 	currentTime: 131065.99999999999
# Processing subtitle 34/107
# 	Content: We also hold a record for hours spent
# in a swimming pool.
# 	Start: 0:02:16.592000
# 	End: 0:02:21.519000
# 	Creating: output/34.mp3
# 	Padding: 5526.000000000015
# 	clip len: 3216
# 	currentTime: 139808.0
# Processing subtitle 35/107
# 	Content: Ivan always had a passion for water.
# 	Start: 0:02:22.686000
# 	End: 0:02:26.042000
# 	Creating: output/35.mp3
# 	Padding: 2878.0
# 	clip len: 2112
# 	currentTime: 144798.0
# Processing subtitle 36/107
# 	Content: I remember when he was two and a half,
# 	Start: 0:02:27.338000
# 	End: 0:02:30.195000
# 	Creating: output/36.mp3
# 	Padding: 2540.0
# 	clip len: 2112
# 	currentTime: 149450.0
# Processing subtitle 37/107
# 	Content: on a rainy winter day,
# 	Start: 0:02:31.265000
# 	End: 0:02:34.565000
# 	Creating: output/37.mp3
# 	Padding: 1815.0
# 	clip len: 1392
# 	currentTime: 152657.0
# Processing subtitle 38/107
# 	Content: I was taking him to an indoor pool,
# 	Start: 0:02:34.589000
# 	End: 0:02:37.065000
# 	Creating: output/38.mp3
# 	Padding: 1932.0
# 	clip len: 2016
# 	currentTime: 156605.0
# Processing subtitle 39/107
# 	Content: because even on rainy days
# we would go swimming.
# 	Start: 0:02:37.089000
# 	End: 0:02:39.739000
# 	Creating: output/39.mp3
# 	Padding: 484.0
# 	clip len: 2568
# 	currentTime: 159657.0
# Processing subtitle 40/107
# 	Content: We were on the highway,
# and I took the wrong exit.
# 	Start: 0:02:41.327000
# 	End: 0:02:45.015000
# 	Creating: output/40.mp3
# 	Padding: 1670.0
# 	clip len: 2832
# 	currentTime: 164159.0
# Processing subtitle 41/107
# 	Content: He burst into tears and cried
# inconsolably, nonstop,
# 	Start: 0:02:45.799000
# 	End: 0:02:49.741000
# 	Creating: output/41.mp3
# 	Padding: 1640.0
# 	clip len: 3648
# 	currentTime: 169447.0
# Processing subtitle 42/107
# 	Content: until I turned back.
# 	Start: 0:02:49.765000
# 	End: 0:02:51.285000
# 	Creating: output/42.mp3
# 	Padding: 318.0
# 	clip len: 1224
# 	currentTime: 170989.0
# Processing subtitle 43/107
# 	Content: Only then did he calm down.
# 	Start: 0:02:52.040000
# 	End: 0:02:53.662000
# 	Creating: output/43.mp3
# 	Padding: 1051.0
# 	clip len: 1680
# 	currentTime: 173720.0
# Processing subtitle 44/107
# 	Content: How was it possible
# that a two and a half year old
# 	Start: 0:02:55.032000
# 	End: 0:02:58.728000
# 	Creating: output/44.mp3
# 	Padding: 1312.0
# 	clip len: 2544
# 	currentTime: 177576.0
# Processing subtitle 45/107
# 	Content: didn't respond to his own name,
# 	Start: 0:02:58.752000
# 	End: 0:03:00.559000
# 	Creating: output/45.mp3
# 	Padding: 1176.0
# 	clip len: 1824
# 	currentTime: 180576.0
# Processing subtitle 46/107
# 	Content: yet in the middle of the rain and fog,
# where I couldn't see anything,
# 	Start: 0:03:01.355000
# 	End: 0:03:05.479000
# 	Creating: output/46.mp3
# 	Padding: 779.0
# 	clip len: 3552
# 	currentTime: 184907.0
# Processing subtitle 47/107
# 	Content: he knew the exact route?
# 	Start: 0:03:05.503000
# 	End: 0:03:09.809000
# 	Creating: output/47.mp3
# 	Padding: 596.0
# 	clip len: 1464
# 	currentTime: 186967.0
# Processing subtitle 48/107
# 	Content: That's when I realized that Ivan
# had an exceptional visual memory,
# 	Start: 0:03:12.570000
# 	End: 0:03:16.010000
# 	Creating: output/48.mp3
# 	Padding: 5603.0
# 	clip len: 3624
# 	currentTime: 196194.0
# Processing subtitle 49/107
# 	Content: and that that would be my way in.
# 	Start: 0:03:17.046000
# 	End: 0:03:20.446000
# 	Creating: output/49.mp3
# 	Padding: 852.0
# 	clip len: 1704
# 	currentTime: 198750.0
# Processing subtitle 50/107
# 	Content: So I started taking
# pictures of everything,
# 	Start: 0:03:21.331000
# 	End: 0:03:23.701000
# 	Creating: output/50.mp3
# 	Padding: 2581.0
# 	clip len: 2280
# 	currentTime: 203611.0
# Processing subtitle 51/107
# 	Content: and teaching him what life was like,
# 	Start: 0:03:24.372000
# 	End: 0:03:26.518000
# 	Creating: output/51.mp3
# 	Padding: 761.0
# 	clip len: 1968
# 	currentTime: 206340.0
# Processing subtitle 52/107
# 	Content: showing it to him, picture by picture.
# 	Start: 0:03:26.542000
# 	End: 0:03:30.132000
# 	Creating: output/52.mp3
# 	Padding: 202.0
# 	clip len: 2448
# 	currentTime: 208990.0
# Processing subtitle 53/107
# 	Content: Even now, it's the way Ivan communicates
# 	Start: 0:03:31.262000
# 	End: 0:03:35.960000
# 	Creating: output/53.mp3
# 	Padding: 2272.0
# 	clip len: 2784
# 	currentTime: 214046.0
# Processing subtitle 54/107
# 	Content: what he wants,
# 	Start: 0:03:35.984000
# 	End: 0:03:37.346000
# 	Creating: output/54.mp3
# 	Padding: 1938.0
# 	clip len: 1056
# 	currentTime: 217040.0
# Processing subtitle 55/107
# 	Content: what he needs
# 	Start: 0:03:37.815000
# 	End: 0:03:39.094000
# 	Creating: output/55.mp3
# 	Padding: 775.0
# 	clip len: 1032
# 	currentTime: 218847.0
# Processing subtitle 56/107
# 	Content: and also what he feels.
# 	Start: 0:03:39.896000
# 	End: 0:03:42.286000
# 	Creating: output/56.mp3
# 	Padding: 1049.0
# 	clip len: 1416
# 	currentTime: 221312.0
# Processing subtitle 57/107
# 	Content: But it wasn't just
# Ivan's eye contact that mattered.
# 	Start: 0:03:45.527000
# 	End: 0:03:48.726000
# 	Creating: output/57.mp3
# 	Padding: 4215.0
# 	clip len: 2616
# 	currentTime: 228143.0
# Processing subtitle 58/107
# 	Content: Everyone else's did, too.
# 	Start: 0:03:50.436000
# 	End: 0:03:52.400000
# 	Creating: output/58.mp3
# 	Padding: 2293.0
# 	clip len: 1824
# 	currentTime: 232260.0
# Processing subtitle 59/107
# 	Content: How could I make people see
# not only his autism,
# 	Start: 0:03:54.239000
# 	End: 0:03:58.229000
# 	Creating: output/59.mp3
# 	Padding: 1979.0
# 	clip len: 2616
# 	currentTime: 236855.0
# Processing subtitle 60/107
# 	Content: but see him the person
# 	Start: 0:03:58.253000
# 	End: 0:03:59.649000
# 	Creating: output/60.mp3
# 	Padding: 1398.0
# 	clip len: 1416
# 	currentTime: 239669.0
# Processing subtitle 61/107
# 	Content: and everything he can give;
# 	Start: 0:04:00.816000
# 	End: 0:04:02.485000
# 	Creating: output/61.mp3
# 	Padding: 1147.0
# 	clip len: 1464
# 	currentTime: 242280.0
# Processing subtitle 62/107
# 	Content: everything he can do;
# 	Start: 0:04:03.820000
# 	End: 0:04:05.566000
# 	Creating: output/62.mp3
# 	Padding: 1540.0
# 	clip len: 1320
# 	currentTime: 245140.0
# Processing subtitle 63/107
# 	Content: the things he likes and doesn't like,
# 	Start: 0:04:06.891000
# 	End: 0:04:09.529000
# 	Creating: output/63.mp3
# 	Padding: 1751.0
# 	clip len: 1896
# 	currentTime: 248787.0
# Processing subtitle 64/107
# 	Content: just like any one of us?
# 	Start: 0:04:09.553000
# 	End: 0:04:11.393000
# 	Creating: output/64.mp3
# 	Padding: 766.0
# 	clip len: 1440
# 	currentTime: 250993.0
# Processing subtitle 65/107
# 	Content: But for that, I also had
# to give of myself.
# 	Start: 0:04:12.815000
# 	End: 0:04:15.885000
# 	Creating: output/65.mp3
# 	Padding: 1822.0
# 	clip len: 2784
# 	currentTime: 255599.0
# Processing subtitle 66/107
# 	Content: I had to have the strength to let him go,
# 	Start: 0:04:17.298000
# 	End: 0:04:19.345000
# 	Creating: output/66.mp3
# 	Padding: 1699.0
# 	clip len: 2064
# 	currentTime: 259362.0
# Processing subtitle 67/107
# 	Content: which was extremely difficult.
# 	Start: 0:04:20.400000
# 	End: 0:04:22.459000
# 	Creating: output/67.mp3
# 	Padding: 1037.999999999971
# 	clip len: 1824
# 	currentTime: 262224.0
# Processing subtitle 68/107
# 	Content: Ivan was 11 years old,
# 	Start: 0:04:24.801000
# 	End: 0:04:26.271000
# 	Creating: output/68.mp3
# 	Padding: 2577.0
# 	clip len: 1824
# 	currentTime: 266625.0
# Processing subtitle 69/107
# 	Content: and he went for treatment
# in a neighborhood near our house.
# 	Start: 0:04:27.259000
# 	End: 0:04:30.949000
# 	Creating: output/69.mp3
# 	Padding: 634.0
# 	clip len: 2856
# 	currentTime: 270115.0
# Processing subtitle 70/107
# 	Content: One afternoon,
# while I was waiting for him,
# 	Start: 0:04:32.297000
# 	End: 0:04:35.728000
# 	Creating: output/70.mp3
# 	Padding: 2182.0
# 	clip len: 2544
# 	currentTime: 274841.0
# Processing subtitle 71/107
# 	Content: I went into a greengrocer,
# 	Start: 0:04:36.367000
# 	End: 0:04:37.703000
# 	Creating: output/71.mp3
# 	Padding: 1526.0
# 	clip len: 1680
# 	currentTime: 278047.0
# Processing subtitle 72/107
# 	Content: a typical neighborhood store
# with a little bit of everything.
# 	Start: 0:04:37.727000
# 	End: 0:04:40.996000
# 	Creating: output/72.mp3
# 	Padding: -320.0
# 	clip len: 3000
# 	currentTime: 280727.0
# Processing subtitle 73/107
# 	Content: While doing the shopping,
# 	Start: 0:04:41.932000
# 	End: 0:04:43.484000
# 	Creating: output/73.mp3
# 	Speed: 1.23
# 	Padding: 0
# 	clip len: 1168
# 	currentTime: 281895.0
# Processing subtitle 74/107
# 	Content: I started talking to Jose, the owner.
# 	Start: 0:04:43.508000
# 	End: 0:04:46.718000
# 	Creating: output/74.mp3
# 	Padding: 1613.0
# 	clip len: 2280
# 	currentTime: 285788.0
# Processing subtitle 75/107
# 	Content: I told him about Ivan,
# 	Start: 0:04:48.446000
# 	End: 0:04:49.829000
# 	Creating: output/75.mp3
# 	Padding: 2658.0
# 	clip len: 1704
# 	currentTime: 290150.0
# Processing subtitle 76/107
# 	Content: that he had autism,
# 	Start: 0:04:50.561000
# 	End: 0:04:51.917000
# 	Creating: output/76.mp3
# 	Padding: 411.0
# 	clip len: 1512
# 	currentTime: 292073.0
# Processing subtitle 77/107
# 	Content: and that I wanted him to learn
# to walk down the street by himself,
# 	Start: 0:04:52.941000
# 	End: 0:04:57.209000
# 	Creating: output/77.mp3
# 	Padding: 868.0
# 	clip len: 3288
# 	currentTime: 296229.0
# Processing subtitle 78/107
# 	Content: without anyone holding his hand.
# 	Start: 0:04:57.233000
# 	End: 0:04:59.333000
# 	Creating: output/78.mp3
# 	Padding: 1004.0
# 	clip len: 1872
# 	currentTime: 299105.0
# Processing subtitle 79/107
# 	Content: So I decided to ask Jose
# if Thursdays around 2pm,
# 	Start: 0:05:00.379000
# 	End: 0:05:04.045000
# 	Creating: output/79.mp3
# 	Padding: 1274.0
# 	clip len: 3408
# 	currentTime: 303787.0
# Processing subtitle 80/107
# 	Content: Ivan could come and help him arrange
# the water bottles on the shelves,
# 	Start: 0:05:05.013000
# 	End: 0:05:08.762000
# 	Creating: output/80.mp3
# 	Padding: 1226.0
# 	clip len: 3408
# 	currentTime: 308421.0
# Processing subtitle 81/107
# 	Content: because he loved to organize things.
# 	Start: 0:05:08.786000
# 	End: 0:05:11.101000
# 	Creating: output/81.mp3
# 	Padding: 365.0
# 	clip len: 2136
# 	currentTime: 310922.0
# Processing subtitle 82/107
# 	Content: And as a reward, he could buy
# some chocolate cookies,
# 	Start: 0:05:11.125000
# 	End: 0:05:14.891000
# 	Creating: output/82.mp3
# 	Padding: 203.0
# 	clip len: 3024
# 	currentTime: 314149.0
# Processing subtitle 83/107
# 	Content: which were his favorite.
# 	Start: 0:05:14.915000
# 	End: 0:05:16.661000
# 	Creating: output/83.mp3
# 	Padding: 766.0
# 	clip len: 1296
# 	currentTime: 316211.0
# Processing subtitle 84/107
# 	Content: He said "yes" right away.
# 	Start: 0:05:19.347000
# 	End: 0:05:20.847000
# 	Creating: output/84.mp3
# 	Padding: 3136.0
# 	clip len: 1536
# 	currentTime: 320883.0
# Processing subtitle 85/107
# 	Content: So that's how it went for a year:
# 	Start: 0:05:22.319000
# 	End: 0:05:25.561000
# 	Creating: output/85.mp3
# 	Padding: 1436.0
# 	clip len: 1824
# 	currentTime: 324143.0
# Processing subtitle 86/107
# 	Content: Ivan would go to Jose's greengrocer,
# 	Start: 0:05:25.585000
# 	End: 0:05:27.875000
# 	Creating: output/86.mp3
# 	Padding: 1442.0
# 	clip len: 2280
# 	currentTime: 327865.0
# Processing subtitle 87/107
# 	Content: help him arrange the shelves
# of water bottles
# 	Start: 0:05:28.816000
# 	End: 0:05:32.260000
# 	Creating: output/87.mp3
# 	Padding: 951.0
# 	clip len: 2400
# 	currentTime: 331216.0
# Processing subtitle 88/107
# 	Content: with the labels perfectly
# lined up on the same side,
# 	Start: 0:05:32.284000
# 	End: 0:05:37.547000
# 	Creating: output/88.mp3
# 	Padding: 1068.0
# 	clip len: 2784
# 	currentTime: 335068.0
# Processing subtitle 89/107
# 	Content: and he would leave happy
# with his chocolate cookies.
# 	Start: 0:05:37.571000
# 	End: 0:05:41.178000
# 	Creating: output/89.mp3
# 	Padding: 2503.0
# 	clip len: 2448
# 	currentTime: 340019.0
# Processing subtitle 90/107
# 	Content: Jose is not an expert in autism.
# 	Start: 0:05:47.558000
# 	End: 0:05:49.978000
# 	Creating: output/90.mp3
# 	Padding: 7539.0
# 	clip len: 2400
# 	currentTime: 349958.0
# Processing subtitle 91/107
# 	Content: There is no need to be an expert
# 	Start: 0:05:52.795000
# 	End: 0:05:55.606000
# 	Creating: output/91.mp3
# 	Padding: 2837.0
# 	clip len: 1752
# 	currentTime: 354547.0
# Processing subtitle 92/107
# 	Content: nor do anything heroic to include someone.
# 	Start: 0:05:56.716000
# 	End: 0:06:00.504000
# 	Creating: output/92.mp3
# 	Padding: 2169.0
# 	clip len: 2664
# 	currentTime: 359380.0
# Processing subtitle 93/107
# 	Content: We just need to be there --
# 	Start: 0:06:03.588000
# 	End: 0:06:05.584000
# 	Creating: output/93.mp3
# 	Padding: 4208.0
# 	clip len: 1416
# 	currentTime: 365004.0
# Processing subtitle 94/107
# 	Content: (Applause)
# 	Start: 0:06:06.019000
# 	End: 0:06:07.591000
# 	Creating: output/94.mp3
# 	Padding: 1015.0
# 	clip len: 936
# 	currentTime: 366955.0
# Processing subtitle 95/107
# 	Content: (Applause ends)
# 	Start: 0:06:14.446000
# 	End: 0:06:16.018000
# 	Creating: output/95.mp3
# 	Padding: 7491.0
# 	clip len: 1176
# 	currentTime: 375622.0
# Processing subtitle 96/107
# 	Content: Really, no heroic deed --
# 	Start: 0:06:17.241000
# 	End: 0:06:18.758000
# 	Creating: output/96.mp3
# 	Padding: 1619.0
# 	clip len: 1992
# 	currentTime: 379233.0
# Processing subtitle 97/107
# 	Content: we simply need to be close.
# 	Start: 0:06:20.481000
# 	End: 0:06:22.773000
# 	Creating: output/97.mp3
# 	Padding: 1248.0
# 	clip len: 1728
# 	currentTime: 382209.0
# Processing subtitle 98/107
# 	Content: And if we are afraid of something
# 	Start: 0:06:25.452000
# 	End: 0:06:27.128000
# 	Creating: output/98.mp3
# 	Padding: 3243.0
# 	clip len: 1800
# 	currentTime: 387252.0
# Processing subtitle 99/107
# 	Content: or we don't understand something,
# 	Start: 0:06:28.015000
# 	End: 0:06:30.199000
# 	Creating: output/99.mp3
# 	Padding: 763.0
# 	clip len: 1848
# 	currentTime: 389863.0
# Processing subtitle 100/107
# 	Content: we need to ask.
# 	Start: 0:06:30.223000
# 	End: 0:06:31.472000
# 	Creating: output/100.mp3
# 	Padding: 360.0
# 	clip len: 1128
# 	currentTime: 391351.0
# Processing subtitle 101/107
# 	Content: Let's be curious
# 	Start: 0:06:32.686000
# 	End: 0:06:34.366000
# 	Creating: output/101.mp3
# 	Padding: 1335.0
# 	clip len: 1320
# 	currentTime: 394006.0
# Processing subtitle 102/107
# 	Content: but never indifferent.
# 	Start: 0:06:35.866000
# 	End: 0:06:39.026000
# 	Creating: output/102.mp3
# 	Padding: 1860.0
# 	clip len: 1296
# 	currentTime: 397162.0
# Processing subtitle 103/107
# 	Content: Let's have the courage
# to look each other in the eye,
# 	Start: 0:06:41.721000
# 	End: 0:06:45.271000
# 	Creating: output/103.mp3
# 	Padding: 4559.0
# 	clip len: 2472
# 	currentTime: 404193.0
# Processing subtitle 104/107
# 	Content: because by looking,
# 	Start: 0:06:47.890000
# 	End: 0:06:49.992000
# 	Creating: output/104.mp3
# 	Padding: 3697.0
# 	clip len: 1296
# 	currentTime: 409186.0
# Processing subtitle 105/107
# 	Content: we can open a whole world to someone else.
# 	Start: 0:06:50.016000
# 	End: 0:06:53.089000
# 	Creating: output/105.mp3
# 	Padding: 830.0
# 	clip len: 2280
# 	currentTime: 412296.0
# Processing subtitle 106/107
# 	Content: (Applause)
# 	Start: 0:06:54.646000
# 	End: 0:06:57.044000
# 	Creating: output/106.mp3
# 	Padding: 2350.0
# 	clip len: 936
# 	currentTime: 415582.0
# Processing subtitle 107/107
# 	Content: (Cheers)
# 	Start: 0:06:57.068000
# 	End: 0:06:59.392000
# 	Creating: output/107.mp3
# 	Padding: 1486.0
# 	clip len: 768
# 	currentTime: 417836.0
# Output file: Enter a name for the output file  (wav):
# ivanOut
# 	Exporting: wav

# %%
IPython.display.Audio("testOutput.wav")

# %%
sound = AudioSegment.from_file("output/6.mp3")
fast = speedChange(sound, 1.01)
fast.export("testOutputfast.wav", format="wav")
IPython.display.Audio("testOutputfast.wav")
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
